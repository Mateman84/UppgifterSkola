# %% [markdown]
# # Matplotlib
# Read the links https://matplotlib.org/stable/users/explain/quick_start.html and https://matplotlib.org/stable/tutorials/pyplot.html before starting the exercises below. The "Pyplot Tutorial" you do not read in detail but it is good to know about since the fact that there are two approaches to plotting can be confusing if you are not aware of both of the approaches.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Plotting in Matplotlib can be done in either of two ways, which ones? Which way is the recommended approach?

# %%
print("There is the OO_style(Object Oriented style and the Pyplot style. Rhe recommended is using the object oriented style)")
# Out:
# There is the OO_style(Object Oriented style and the Pyplot style. Rhe recommended is using the object oriented style)

# %% [markdown]
# ### Explain shortly what a figure, axes, axis and an artist is in Matplotlib.

# %%
print("Figure:\nThe Figure keeps track of all the child Axes, a group of 'special' Artists (titles, figure legends, colorbars, etc.), and even nested subfigures.\n")
print("Axes:\nAn Axes object encapsulates all the elements of an individual (sub-)plot in a figure. \nIt is an Artist attached to a Figure that contains a region for plotting data, and usually includes two (or three in the case of 3D) Axis objects\n")
print("Axis:\nAn Axis is a (sub-)plot element of en axes. These objects set the scale and limits and generate ticks (the marks on the Axis)\n")
print("Artist:\nBasically, everything visible on the Figure is an Artist")
# Out:
# Figure:
# The Figure keeps track of all the child Axes, a group of 'special' Artists (titles, figure legends, colorbars, etc.), and even nested subfigures.
#
# Axes:
# An Axes object encapsulates all the elements of an individual (sub-)plot in a figure.
# It is an Artist attached to a Figure that contains a region for plotting data, and usually includes two (or three in the case of 3D) Axis objects
#
# Axis:
# An Axis is a (sub-)plot element of en axes. These objects set the scale and limits and generate ticks (the marks on the Axis)
#
# Artist:
# Basically, everything visible on the Figure is an Artist

# %% [markdown]
# ### When plotting in Matplotlib, what is the expected input data type?

# %%
print("Expected input data type is array like data")
# Out:
# Expected input data type is array like data

# %% [markdown]
# ### Create a plot of the function y = x^2 [from -4 to 4, hint use the np.linspace function] both in the object-oriented approach and the pyplot approach. Your plot should have a title and axis-labels.

# %%
x = np.linspace(-4, 4, 100)
y = x**2

plt.plot(x, y)
plt.title("Parabola 1 by Mattias")
plt.xlabel("x")
plt.ylabel("y")
plt.show()

fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_title("Parabola 2 by Mattias")
ax.set_xlabel("x")
ax.set_ylabel("y")
plt.show()

# %% [markdown]
# ### Create a figure containing 2  subplots where the first is a scatter plot and the second is a bar plot. You have the data below.

# %%
# Data for scatter plot
np.random.seed(15)
random_data_x = np.random.randn(1000)
random_data_y = np.random.randn(1000)

# Data for bar plot
fruit_data = {'grapes': 22, 'apple': 8, 'orange': 15, 'lemon': 20, 'lime': 25}
names = list(fruit_data.keys())
values = list(fruit_data.values())

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

# Scatter plot
axes[0].scatter(random_data_x, random_data_y)
axes[0].set_title("Scatter Plot by Mattias")
axes[0].set_xlabel("X values")
axes[0].set_ylabel("Y values")

# Bar plot
axes[1].bar(names, values)
axes[1].set_title("Bar Plot by Mattias")
axes[1].set_xlabel("Fruit")
axes[1].set_ylabel("Quantity")

plt.tight_layout()
plt.show()
